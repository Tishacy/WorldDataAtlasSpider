# %% [markdown]
# # Handbook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from knoema.knoema import Country
from knoema.utils import *

# %% [markdown]
# ## 1. 可供查询的国家/地区和指标
#
# ### 1.1 国家/地区

# %%
print("共 %d 个国家/地区" %(len(countries)))
pd.DataFrame(countries).head(10)
# Out:
# 共 197 个国家/地区
#         id                         name
# 0  1000380                      Vanuatu
# 1  1001840     Central-African-Republic
# 2  1001090                     Colombia
# 3  1000540                      Estonia
# 4  1002170                  South-Sudan
# 5  1000460                      Belgium
# 6  1001260                     Paraguay
# 7  1000030                    Australia
# 8  1001310                  Saint-Lucia
# 9  1002200  United-Republic-of-Tanzania

# %% [markdown]
# ### 1.2 指标

# %%
print("共 %d 个指标" %(len(indicators)))
pd.DataFrame(indicators).head(10)
# Out:
# 共 147 个指标
#         id                                        name
# 0  1007460                  Livestock-production-index
# 1  1000030                                         GDP
# 2  1015800  Expenditures-for-passenger-transport-items
# 3  1000010                Global-competitiveness-index
# 4  1008580         Forest-area-as-a-share-of-land-area
# 5  1000720     Government-gross-debt-as-a-share-of-GDP
# 6  1001350          Population-aged-65-years-and-above
# 7  1013970              Poverty-rate-at-dollar19-a-day
# 8  1010510                        Child-mortality-rate
# 9  1000500                           Unemployment-rate

# %% [markdown]
# ## 2. 查询
#
# 1. 查询某国/地区某一年的某指标数据
# ```python
# data = Country('国名/地区名').query('指标名', '年份')
# ```
# 1. 查询某国/地区的指标数据（所有可查年份）
# ```python
# data = Country('国名/地区名').fetch_data('指标名', '年份')
# ```
#
# ### 2.1 查询某一年的指标
# 比如，中国2018年的GDP数据为：

# %%
data = Country('China').query('GDP', '2018')
data
# Out:
# [{'Time': '2018-01-01T00:00:00Z',
#   'country': 'China',
#   'RegionId': 'CN',
#   'subject': 'Gross domestic product, current prices (U.S. dollars)',
#   'Frequency': 'A',
#   'Value': 13407.4,
#   'Unit': 'U.S. dollars, Billions',
#   'Scale': 1}]

# %% [markdown]
# 转换成`DataFrame`格式为：

# %%
pd.DataFrame(data)
# Out:
#   Frequency RegionId  Scale                  Time                    Unit  \
# 0         A       CN      1  2018-01-01T00:00:00Z  U.S. dollars, Billions
#
#      Value country                                            subject
# 0  13407.4   China  Gross domestic product, current prices (U.S. d...

# %% [markdown]
# ### 2.2 查询所有可查年份的指标
#
# 比如，中国可查的GDP数据：

# %%
data = Country('China').fetch_data('GDP')
pd.DataFrame(data)
# Out:
#    Frequency RegionId  Scale                  Time                    Unit  \
# 0          A       CN      1  1980-01-01T00:00:00Z  U.S. dollars, Billions
# 1          A       CN      1  1981-01-01T00:00:00Z  U.S. dollars, Billions
# 2          A       CN      1  1982-01-01T00:00:00Z  U.S. dollars, Billions
# 3          A       CN      1  1983-01-01T00:00:00Z  U.S. dollars, Billions
# 4          A       CN      1  1984-01-01T00:00:00Z  U.S. dollars, Billions
# 5          A       CN      1  1985-01-01T00:00:00Z  U.S. dollars, Billions
# 6          A       CN      1  1986-01-01T00:00:00Z  U.S. dollars, Billions
# 7          A       CN      1  1987-01-01T00:00:00Z  U.S. dollars, Billions
# 8          A       CN      1  1988-01-01T00:00:00Z  U.S. dollars, Billions
# 9          A       CN      1  1989-01-01T00:00:00Z  U.S. dollars, Billions
# 10         A       CN      1  1990-01-01T00:00:00Z  U.S. dollars, Billions
# 11         A       CN      1  1991-01-01T00:00:00Z  U.S. dollars, Billions
# 12         A       CN      1  1992-01-01T00:00:00Z  U.S. dollars, Billions
# 13         A       CN      1  1993-01-01T00:00:00Z  U.S. dollars, Billions
# 14         A       CN      1  1994-01-01T00:00:00Z  U.S. dollars, Billions
# 15         A       CN      1  1995-01-01T00:00:00Z  U.S. dollars, Billions
# 16         A       CN      1  1996-01-01T00:00:00Z  U.S. dollars, Billions
# 17         A       CN      1  1997-01-01T00:00:00Z  U.S. dollars, Billions
# 18         A       CN      1  1998-01-01T00:00:00Z  U.S. dollars, Billions
# 19         A       CN      1  1999-01-01T00:00:00Z  U.S. dollars, Billions
# 20         A       CN      1  2000-01-01T00:00:00Z  U.S. dollars, Billions
# 21         A       CN      1  2001-01-01T00:00:00Z  U.S. dollars, Billions
# 22         A       CN      1  2002-01-01T00:00:00Z  U.S. dollars, Billions
# 23         A       CN      1  2003-01-01T00:00:00Z  U.S. dollars, Billions
# 24         A       CN      1  2004-01-01T00:00:00Z  U.S. dollars, Billions
# 25         A       CN      1  2005-01-01T00:00:00Z  U.S. dollars, Billions
# 26         A       CN      1  2006-01-01T00:00:00Z  U.S. dollars, Billions
# 27         A       CN      1  2007-01-01T00:00:00Z  U.S. dollars, Billions
# 28         A       CN      1  2008-01-01T00:00:00Z  U.S. dollars, Billions
# 29         A       CN      1  2009-01-01T00:00:00Z  U.S. dollars, Billions
# 30         A       CN      1  2010-01-01T00:00:00Z  U.S. dollars, Billions
# 31         A       CN      1  2011-01-01T00:00:00Z  U.S. dollars, Billions
# 32         A       CN      1  2012-01-01T00:00:00Z  U.S. dollars, Billions
# 33         A       CN      1  2013-01-01T00:00:00Z  U.S. dollars, Billions
# 34         A       CN      1  2014-01-01T00:00:00Z  U.S. dollars, Billions
# 35         A       CN      1  2015-01-01T00:00:00Z  U.S. dollars, Billions
# 36         A       CN      1  2016-01-01T00:00:00Z  U.S. dollars, Billions
# 37         A       CN      1  2017-01-01T00:00:00Z  U.S. dollars, Billions
# 38         A       CN      1  2018-01-01T00:00:00Z  U.S. dollars, Billions
#
#         Value country                                            subject
# 0     305.348   China  Gross domestic product, current prices (U.S. d...
# 1     290.827   China  Gross domestic product, current prices (U.S. d...
# 2     286.719   China  Gross domestic product, current prices (U.S. d...
# 3     307.677   China  Gross domestic product, current prices (U.S. d...
# 4     316.628   China  Gross domestic product, current prices (U.S. d...
# 5     312.616   China  Gross domestic product, current prices (U.S. d...
# 6     303.340   China  Gross domestic product, current prices (U.S. d...
# 7     330.303   China  Gross domestic product, current prices (U.S. d...
# 8     411.923   China  Gross domestic product, current prices (U.S. d...
# 9     461.066   China  Gross domestic product, current prices (U.S. d...
# 10    398.623   China  Gross domestic product, current prices (U.S. d...
# 11    415.604   China  Gross domestic product, current prices (U.S. d...
# 12    495.671   China  Gross domestic product, current prices (U.S. d...
# 13    623.054   China  Gross domestic product, current prices (U.S. d...
# 14    566.471   China  Gross domestic product, current prices (U.S. d...
# 15    736.870   China  Gross domestic product, current prices (U.S. d...
# 16    867.224   China  Gross domestic product, current prices (U.S. d...
# 17    965.338   China  Gross domestic product, current prices (U.S. d...
# 18   1032.570   China  Gross domestic product, current prices (U.S. d...
# 19   1097.140   China  Gross domestic product, current prices (U.S. d...
# 20   1214.920   China  Gross domestic product, current prices (U.S. d...
# 21   1344.080   China  Gross domestic product, current prices (U.S. d...
# 22   1477.500   China  Gross domestic product, current prices (U.S. d...
# 23   1671.070   China  Gross domestic product, current prices (U.S. d...
# 24   1966.240   China  Gross domestic product, current prices (U.S. d...
# 25   2308.800   China  Gross domestic product, current prices (U.S. d...
# 26   2774.290   China  Gross domestic product, current prices (U.S. d...
# 27   3571.450   China  Gross domestic product, current prices (U.S. d...
# 28   4604.290   China  Gross domestic product, current prices (U.S. d...
# 29   5121.680   China  Gross domestic product, current prices (U.S. d...
# 30   6066.350   China  Gross domestic product, current prices (U.S. d...
# 31   7522.100   China  Gross domestic product, current prices (U.S. d...
# 32   8570.350   China  Gross domestic product, current prices (U.S. d...
# 33   9635.030   China  Gross domestic product, current prices (U.S. d...
# 34  10534.530   China  Gross domestic product, current prices (U.S. d...
# 35  11226.190   China  Gross domestic product, current prices (U.S. d...
# 36  11221.840   China  Gross domestic product, current prices (U.S. d...
# 37  12062.280   China  Gross domestic product, current prices (U.S. d...
# 38  13407.400   China  Gross domestic product, current prices (U.S. d...

# %% [markdown]
# ## 3. 比较不同国家的指标数据
#
# 如`demo.py`文件中对中美两国的Population数据比较。

# %%
# !cat demo.py
# Out:
# # coding: utf-8
# """Demo: Comparison of GDP between USA and China from 1980-2014
# """
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
#
# from knoema.knoema import Country
# from knoema.utils import *
#
#
# # Fetch data
# INDIC = 'Population'
# CN, USA = Country('China'), Country('USA')
# CN_data, USA_data = CN.fetch_data(INDIC), USA.fetch_data(INDIC)
# CN_df, USA_df = pd.DataFrame(CN_data), pd.DataFrame(USA_data)
# print('已获取数据')
#
# # Visualization
# fig = plt.figure(figsize=(8, 4.5))
# frm = int(CN_data[0]['Time'][:4])
#
# plt.plot(np.arange(frm, frm + len(CN_data)), 'Value', '-', color='r', data=CN_df, label='CN')
# plt.plot(np.arange(frm, frm + len(USA_data)), 'Value', '-', color='k', data=USA_df, label='USA')
# plt.xlabel('Time (a)', fontsize=14)
# plt.ylabel('{0} ({1})'.format(INDIC, CN_data[0]['Unit']), fontsize=14)
# plt.title('Comparison of %s between USA and CN' %(INDIC), fontsize=15)
# plt.legend(fontsize=12)
# fig.autofmt_xdate()
#
# plt.show()

# %%
import demo
# Out:
# 已获取数据
